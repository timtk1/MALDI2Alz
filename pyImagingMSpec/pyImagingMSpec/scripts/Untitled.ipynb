# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('/Users/palmer/Documents/python_codebase/')
from pyMSpec.centroid_detection import gradient
from pyImagingMSpec.inMemoryIMS import inMemoryIMS
from pyImagingMSpec import image_measures
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
filename_in =  '//home/palmer/Documents/tmp_data/URenn/MB/Brain01_Bregma1-42/regions - no normalization.imzML' #using a temporary hdf5 based format
save_dir='/home/palmer/Documents/tmp_data/URenn/MB/Brain01_Bregma1-42/autogen/'

# Parse data
IMS_dataset=inMemoryIMS(filename_in)
ppm = 0.75
# Out:
# TODO: convert indices into real world coordinates
# loaded spectra
# file loaded

# %%
plt.figure()
for r in np.random.choice(10,len(IMS_dataset.index_list)):
    spec = IMS_dataset.get_spectrum(r).get_spectrum(source='centroids')
    plt.plot(spec[0],spec[0] - np.floor(spec[0]) ,'x', marker = (4, 2, (r/10.)*360.), markersize= 24)
plt.show()
# Out:
# <img src="data:image/png;base64,...">
